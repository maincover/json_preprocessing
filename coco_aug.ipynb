# %%
import imageio
import imgaug as ia
# %matplotlib inline

image = imageio.imread("https://upload.wikimedia.org/wikipedia/commons/f/f4/Tamias_striatus_CT.jpg")
image = ia.imresize_single_image(image, 0.15)
print(image.shape)
ia.imshow(image)
# Out:
# (319, 479, 3)

# %%
# %matplotlib inline
from pycocotools.coco import COCO
import numpy as np
import skimage.io as io
import matplotlib.pyplot as plt
import pylab
pylab.rcParams['figure.figsize'] = (8.0, 10.0)
# %pwd
# Out:
# '/Users/xsong/Desktop/Felix eggs'

# %%
import json
f='./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/annotations/instances_default.json'
coco=COCO(f)

cats = coco.loadCats(coco.getCatIds())
nms=[cat['name'] for cat in cats]
print('COCO categories: \n{}\n'.format(' '.join(nms)))

nms = set([cat['supercategory'] for cat in cats])
print('COCO supercategories: \n{}'.format(' '.join(nms)))
# Out:
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# COCO categories:
# egg
#
# COCO supercategories:

# %%
# get all images containing given categories, select one at random
catIds = coco.getCatIds(catNms=['egg']);
imgIds = coco.getImgIds(catIds=catIds );
print(imgIds)
#imgIds = coco.getImgIds(imgIds = [324158])
img = coco.loadImgs(imgIds[np.random.randint(0,len(imgIds))])[0]
# load and display image
dataDir = './task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images'
#I = io.imread('%s/images/%s/%s'%(dataDir,dataType,img['file_name']))
# use url to load image
print(img['coco_url'])
print(img)
# Out:
# [1, 5, 6, 7, 8, 9]
#
# {'id': 5, 'width': 2598, 'height': 1293, 'file_name': '200728_eggs0004.tif', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}

# %%
import numpy as np
import imgaug as ia
import imgaug.augmenters as iaa


ia.seed(1)

# Example batch of images.
# The array has shape (32, 64, 64, 3) and dtype uint8.
images = np.array(
    [ia.quokka(size=(64, 64)) for _ in range(32)],
    dtype=np.uint8
)

seq = iaa.Sequential([
    iaa.Fliplr(0.5), # horizontal flips
    iaa.Crop(percent=(0, 0.1)), # random crops
    # Small gaussian blur with random sigma between 0 and 0.5.
    # But we only blur about 50% of all images.
    iaa.Sometimes(
        0.5,
        iaa.GaussianBlur(sigma=(0, 0.5))
    ),
    # Strengthen or weaken the contrast in each image.
    iaa.LinearContrast((0.75, 1.5)),
    # Add gaussian noise.
    # For 50% of all images, we sample the noise once per pixel.
    # For the other 50% of all images, we sample the noise per pixel AND
    # channel. This can change the color (not only brightness) of the
    # pixels.
    iaa.AdditiveGaussianNoise(loc=0, scale=(0.0, 0.05*255), per_channel=0.5),
    # Make some images brighter and some darker.
    # In 20% of all cases, we sample the multiplier once per channel,
    # which can end up changing the color of the images.
    iaa.Multiply((0.8, 1.2), per_channel=0.2),
    # Apply affine transformations to each image.
    # Scale/zoom them, translate/move them, rotate them and shear them.
    iaa.Affine(
        scale={"x": (0.8, 1.2), "y": (0.8, 1.2)},
        translate_percent={"x": (-0.2, 0.2), "y": (-0.2, 0.2)},
        rotate=(-25, 25),
        shear=(-8, 8)
    )
], random_order=True) # apply augmenters in random order

images_aug = seq(images=images)

# %%
images_aug.shape
# Out:
# (32, 64, 64, 3)

# %%
import IPython
import os
import json
import random
import numpy as np
import requests
from io import BytesIO
import base64
from math import trunc
from PIL import Image as PILImage
from PIL import ImageDraw as PILImageDraw

# %%
class CocoDataset():
    def __init__(self, annotation_path, image_dir):
        self.annotation_path = annotation_path
        self.image_dir = image_dir
        self.colors = colors = ['blue', 'purple', 'red', 'green', 'orange', 'salmon', 'pink', 'gold',
                                'orchid', 'slateblue', 'limegreen', 'seagreen', 'darkgreen', 'olive',
                               'teal', 'aquamarine', 'steelblue', 'powderblue', 'dodgerblue', 'navy',
                               'magenta', 'sienna', 'maroon']
        
        json_file = open(self.annotation_path)
        self.coco = json.load(json_file)
        json_file.close()
        
        self.process_info()
        self.process_licenses()
        self.process_categories()
        self.process_images()
        self.process_segmentations()
            
        
    def display_info(self):
        print('Dataset Info:')
        print('=============')
        for key, item in self.info.items():
            print('  {}: {}'.format(key, item))
        
        requirements = [['description', str],
                        ['url', str],
                        ['version', str],
                        ['year', int],
                        ['contributor', str],
                        ['date_created', str]]
        for req, req_type in requirements:
            if req not in self.info:
                print('ERROR: {} is missing'.format(req))
            elif type(self.info[req]) != req_type:
                print('ERROR: {} should be type {}'.format(req, str(req_type)))
        print('')

        
    def display_licenses(self):
        print('Licenses:')
        print('=========')
        
        requirements = [['id', int],
                        ['url', str],
                        ['name', str]]
        for license in self.licenses:
            for key, item in license.items():
                print('  {}: {}'.format(key, item))
            for req, req_type in requirements:
                if req not in license:
                    print('ERROR: {} is missing'.format(req))
                elif type(license[req]) != req_type:
                    print('ERROR: {} should be type {}'.format(req, str(req_type)))
            print('')
        print('')
        
    def display_categories(self):
        print('Categories:')
        print('=========')
        for sc_key, sc_val in self.super_categories.items():
            print('  super_category: {}'.format(sc_key))
            for cat_id in sc_val:
                print('    id {}: {}'.format(cat_id, self.categories[cat_id]['name']))
            print('')
    
    def display_image(self, image_id, show_polys=True, show_bbox=True, show_crowds=True, use_url=False, save_mask=False):
        print('Image:')
        print('======')
        if image_id == 'random':
            image_id = random.choice(list(self.images.keys()))
        
        # Print the image info
        image = self.images[image_id]
        for key, val in image.items():
            print('  {}: {}'.format(key, val))
            
        # Open the image
        if use_url:
            image_path = image['coco_url']
            response = requests.get(image_path)
            image = PILImage.open(BytesIO(response.content))
            
        else:
            image_path = os.path.join(self.image_dir, image['file_name'])
            image = PILImage.open(image_path)
            draw = PILImageDraw.Draw(image)
            #draw.polygon([500,500,562,432,562,431,562,430,562,430,562,429])
            buffer = BytesIO()
            image.save(buffer, format='PNG')
            buffer.seek(0)
            
            data_uri = base64.b64encode(buffer.read()).decode('ascii')
            image_path = "data:image/png;base64,{0}".format(data_uri)
            
        # Calculate the size and adjusted display size
        max_width = 1024
        image_width, image_height = image.size
        adjusted_width = min(image_width, max_width)
        adjusted_ratio = adjusted_width / image_width
        adjusted_height = adjusted_ratio * image_height
        
        
        
        # Create list of polygons to be drawn
        polygons = {}
        self.polygons_no_scale = {}
        bbox_polygons = {}
        rle_regions = {}
        poly_colors = {}
        print('  segmentations ({}):'.format(len(self.segmentations[image_id])))
        for i, segm in enumerate(self.segmentations[image_id]):
            polygons_list = []
            polygons_list_no_scale = []
            if segm['iscrowd'] != 0:
                # Gotta decode the RLE
                px = 0
                x, y = 0, 0
                rle_list = []
                for j, counts in enumerate(segm['segmentation']['counts']):
                    if j % 2 == 0:
                        # Empty pixels
                        px += counts
                    else:
                        # Need to draw on these pixels, since we are drawing in vector form,
                        # we need to draw horizontal lines on the image
                        x_start = trunc(trunc(px / image_height) * adjusted_ratio)
                        y_start = trunc(px % image_height * adjusted_ratio)
                        px += counts
                        x_end = trunc(trunc(px / image_height) * adjusted_ratio)
                        y_end = trunc(px % image_height * adjusted_ratio)
                        if x_end == x_start:
                            # This is only on one line
                            rle_list.append({'x': x_start, 'y': y_start, 'width': 1 , 'height': (y_end - y_start)})
                        if x_end > x_start:
                            # This spans more than one line
                            # Insert top line first
                            rle_list.append({'x': x_start, 'y': y_start, 'width': 1, 'height': (image_height - y_start)})
                            
                            # Insert middle lines if needed
                            lines_spanned = x_end - x_start + 1 # total number of lines spanned
                            full_lines_to_insert = lines_spanned - 2
                            if full_lines_to_insert > 0:
                                full_lines_to_insert = trunc(full_lines_to_insert * adjusted_ratio)
                                rle_list.append({'x': (x_start + 1), 'y': 0, 'width': full_lines_to_insert, 'height': image_height})
                                
                            # Insert bottom line
                            rle_list.append({'x': x_end, 'y': 0, 'width': 1, 'height': y_end})
                if len(rle_list) > 0:
                    rle_regions[segm['id']] = rle_list  
            else:
                # Add the polygon segmentation
                for segmentation_points in segm['segmentation']:
                    polygons_list_no_scale.append(segmentation_points)
                    segmentation_points = np.multiply(segmentation_points, adjusted_ratio).astype(int)
                    polygons_list.append(str(segmentation_points).lstrip('[').rstrip(']'))
            polygons[segm['id']] = polygons_list
            self.polygons_no_scale[segm['id']] = polygons_list_no_scale
            if i < len(self.colors):
                poly_colors[segm['id']] = self.colors[i]
            else:
                poly_colors[segm['id']] = 'white'
            
            bbox = segm['bbox']
            bbox_points = [bbox[0], bbox[1], bbox[0] + bbox[2], bbox[1],
                           bbox[0] + bbox[2], bbox[1] + bbox[3], bbox[0], bbox[1] + bbox[3],
                           bbox[0], bbox[1]]
            bbox_points = np.multiply(bbox_points, adjusted_ratio).astype(int)
            bbox_polygons[segm['id']] = str(bbox_points).lstrip('[').rstrip(']')
            
            # Print details
            print('    {}:{}:{}'.format(segm['id'], poly_colors[segm['id']], self.categories[segm['category_id']]))
        
        
        
        # Draw segmentation polygons on image
        html  = '<div class="container" style="position:relative;">'
        html += '<img src="{}" style="position:relative;top:0px;left:0px;width:{}px;">'.format(image_path, adjusted_width)
        html += '<div class="svgclass"><svg width="{}" height="{}">'.format(adjusted_width, adjusted_height)
        
        if show_polys:
            for seg_id, points_list in self.polygons_no_scale.items():
                draw.polygon(points_list[0],fill=20000000000)
                if save_mask:
                    print(points_list[0])
                
            image.show()
            for seg_id, points_list in polygons.items():
                fill_color = poly_colors[seg_id]
                stroke_color = poly_colors[seg_id]
                for points in points_list:
                    html += '<polygon points="{}" style="fill:{}; stroke:{}; stroke-width:1; fill-opacity:0.5" />'.format(points, fill_color, stroke_color)
            
            
        if show_crowds:
            for seg_id, rect_list in rle_regions.items():
                fill_color = poly_colors[seg_id]
                stroke_color = poly_colors[seg_id]
                for rect_def in rect_list:
                    x, y = rect_def['x'], rect_def['y']
                    w, h = rect_def['width'], rect_def['height']
                    html += '<rect x="{}" y="{}" width="{}" height="{}" style="fill:{}; stroke:{}; stroke-width:1; fill-opacity:0.5; stroke-opacity:0.5" />'.format(x, y, w, h, fill_color, stroke_color)
            
        if show_bbox:
            for seg_id, points in bbox_polygons.items():
                fill_color = poly_colors[seg_id]
                stroke_color = poly_colors[seg_id]
                html += '<polygon points="{}" style="fill:{}; stroke:{}; stroke-width:1; fill-opacity:0" />'.format(points, fill_color, stroke_color)
                
        html += '</svg></div>'
        html += '</div>'
        html += '<style>'
        html += '.svgclass { position:absolute; top:0px; left:0px;}'
        html += '</style>'
        return html
       
    def process_info(self):
        self.info = self.coco['info']
    
    def process_licenses(self):
        self.licenses = self.coco['licenses']
    
    def process_categories(self):
        self.categories = {}
        self.super_categories = {}
        for category in self.coco['categories']:
            cat_id = category['id']
            super_category = category['supercategory']
            
            # Add category to the categories dict
            if cat_id not in self.categories:
                self.categories[cat_id] = category
            else:
                print("ERROR: Skipping duplicate category id: {}".format(category))

            # Add category to super_categories dict
            if super_category not in self.super_categories:
                self.super_categories[super_category] = {cat_id} # Create a new set with the category id
            else:
                self.super_categories[super_category] |= {cat_id} # Add category id to the set
                
    def process_images(self):
        self.images = {}
        for image in self.coco['images']:
            image_id = image['id']
            if image_id in self.images:
                print("ERROR: Skipping duplicate image id: {}".format(image))
            else:
                self.images[image_id] = image
                
    def process_segmentations(self):
        self.segmentations = {}
        for segmentation in self.coco['annotations']:
            image_id = segmentation['image_id']
            if image_id not in self.segmentations:
                self.segmentations[image_id] = []
            self.segmentations[image_id].append(segmentation)

# %%
annotation_path = './task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/annotations/instances_default.json'
image_dir = './task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images'
coco_dataset = CocoDataset(annotation_path, image_dir)
coco_dataset.display_info()
coco_dataset.display_licenses()
coco_dataset.display_categories()
# Out:
# Dataset Info:
# =============
#   contributor:
#   date_created:
#   description:
#   url:
#   version:
#   year:
# ERROR: year should be type <class 'int'>
#
# Licenses:
# =========
#   name:
#   id: 0
#   url:
#
#
# Categories:
# =========
#   super_category:
#     id 1: egg

# %%
image_id = 5
html = coco_dataset.display_image(image_id, use_url=False,show_polys=True,show_bbox=False)
IPython.display.HTML(html)
# Out:
# Image:
# ======
#   id: 5
#   width: 2598
#   height: 1293
#   file_name: 200728_eggs0004.tif
#   license: 0
#   flickr_url:
#   coco_url:
#   date_captured: 0
#   segmentations (576):
#     103:blue:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     104:purple:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     105:red:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     106:green:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     107:orange:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     108:salmon:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     109:pink:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     110:gold:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     111:orchid:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     112:slateblue:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     113:limegreen:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     114:seagreen:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     115:darkgreen:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     116:olive:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     117:teal:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     118:aquamarine:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     119:steelblue:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     120:powderblue:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     121:dodgerblue:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     122:navy:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     123:magenta:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     124:sienna:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     125:maroon:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     126:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     127:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     128:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     129:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     130:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     131:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     132:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     133:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     134:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     135:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     136:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     137:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     138:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     139:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     140:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     141:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     142:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     143:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     144:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     145:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     146:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     147:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     148:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     149:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     150:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     151:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     152:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     153:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     154:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     155:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     156:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     157:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     158:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     159:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     160:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     161:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     162:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     163:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     164:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     165:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     166:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     167:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     168:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     169:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     170:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     171:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     172:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     173:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     174:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     175:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     176:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     177:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     178:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     179:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     180:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     181:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     182:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     183:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     184:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     185:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     186:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     187:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     188:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     189:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     190:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     191:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     192:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     193:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     194:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     195:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     196:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     197:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     198:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     199:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     200:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     201:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     202:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     203:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     204:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     205:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     206:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     207:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     208:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     209:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     210:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     211:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     212:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     213:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     214:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     215:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     216:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     217:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     218:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     219:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     220:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     221:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     222:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     223:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     224:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     225:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     226:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     227:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     228:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     229:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     230:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     231:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     232:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     233:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     234:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     235:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     236:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     237:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     238:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     239:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     240:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     241:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     242:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     243:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     244:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     245:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     246:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     247:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     248:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     249:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     250:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     251:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     252:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     253:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     254:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     255:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     256:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     257:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     258:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     259:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     260:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     261:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     262:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     263:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     264:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     265:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     266:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     267:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     268:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     269:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     270:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     271:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     272:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     273:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     274:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     275:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     276:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     277:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     278:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     279:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     280:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     281:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     282:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     283:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     284:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     285:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     286:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     287:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     288:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     289:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     290:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     291:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     292:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     293:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     294:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     295:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     296:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     297:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     298:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     299:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     300:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     301:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     302:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     303:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     304:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     305:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     306:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     307:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     308:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     309:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     310:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     311:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     312:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     313:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     314:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     315:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     316:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     317:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     318:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     319:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     320:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     321:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     322:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     323:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     324:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     325:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     326:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     327:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     328:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     329:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     330:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     331:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     332:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     333:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     334:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     335:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     336:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     337:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     338:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     339:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     340:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     341:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     342:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     343:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     344:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     345:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     346:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     347:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     348:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     349:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     350:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     351:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     352:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     353:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     354:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     355:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     356:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     357:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     358:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     359:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     360:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     361:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     362:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     363:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     364:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     365:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     366:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     367:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     368:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     369:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     370:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     371:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     372:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     373:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     374:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     375:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     376:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     377:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     378:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     379:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     380:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     381:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     382:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     383:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     384:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     385:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     386:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     387:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     388:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     389:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     390:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     391:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     392:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     393:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     394:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     395:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     396:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     397:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     398:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     399:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     400:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     401:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     402:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     403:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     404:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     405:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     406:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     407:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     408:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     409:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     410:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     411:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     412:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     413:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     414:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     415:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     416:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     417:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     418:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     419:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     420:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     421:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     422:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     423:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     424:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     425:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     426:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     427:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     428:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     429:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     430:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     431:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     432:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     433:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     434:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     435:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     436:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     437:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     438:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     439:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     440:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     441:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     442:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     443:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     444:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     445:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     446:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     447:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     448:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     449:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     450:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     451:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     452:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     453:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     454:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     455:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     456:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     457:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     458:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     459:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     460:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     461:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     462:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     463:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     464:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     465:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     466:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     467:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     468:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     469:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     470:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     471:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     472:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     473:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     474:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     475:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     476:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     477:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     478:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     479:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     480:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     481:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     482:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     483:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     484:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     485:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     486:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     487:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     488:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     489:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     490:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     491:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     492:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     493:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     494:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     495:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     496:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     497:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     498:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     499:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     500:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     501:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     502:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     503:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     504:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     505:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     506:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     507:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     508:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     509:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     510:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     511:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     512:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     513:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     514:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     515:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     516:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     517:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     518:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     519:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     520:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     521:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     522:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     523:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     524:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     525:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     526:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     527:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     528:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     529:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     530:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     531:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     532:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     533:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     534:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     535:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     536:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     537:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     538:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     539:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     540:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     541:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     542:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     543:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     544:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     545:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     546:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     547:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     548:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     549:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     550:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     551:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     552:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     553:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     554:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     555:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     556:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     557:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     558:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     559:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     560:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     561:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     562:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     563:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     564:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     565:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     566:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     567:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     568:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     569:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     570:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     571:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     572:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     573:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     574:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     575:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     576:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     577:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     578:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     579:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     580:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     581:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     582:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     583:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     584:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     585:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     586:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     587:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     588:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     589:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     590:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     591:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     592:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     593:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     594:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     595:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     596:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     597:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     598:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     599:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     600:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     601:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     602:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     603:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     604:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     605:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     606:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     607:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     608:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     609:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     610:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     611:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     612:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     613:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     614:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     615:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     616:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     617:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     618:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     619:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     620:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     621:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     622:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     623:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     624:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     625:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     626:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     627:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     628:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     629:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     630:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     631:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     632:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     633:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     634:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     635:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     636:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     637:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     638:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     639:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     640:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     641:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     642:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     643:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     644:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     645:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     646:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     647:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     648:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     649:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     650:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     651:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     652:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     653:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     654:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     655:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     656:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     657:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     658:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     659:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     660:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     661:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     662:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     663:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     664:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     665:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     666:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     667:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     668:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     669:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     670:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     671:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     672:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     673:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     674:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     675:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     676:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     677:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     678:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
# <div class="container" style="position:relative;"><img src="data:image/png;base64,..." style="position:relative;top:0px;left:0px;width:1024px;"><div class="svgclass"><svg width="1024" height="509.635103926097"><polygon points="562 432 562 432 562 431 562 430 562 430 562 429 562 428 562 428 562 427
#  562 426 562 426 563 425 563 425 564 425 564 425 564 426 564 427 565 427
#  565 428 564 428 564 429 564 430 564 430 564 431 564 432 564 432 564 433
#  564 433 564 434 563 434 563 434 563 433" style="fill:blue; stroke:blue; stroke-width:1; fill-opacity:0.5" /><polygon points="233 345 234 345 234 344 235 344 236 344 236 344 237 343 237 343 238 343
#  239 343 239 343 240 342 241 342 241 342 242 343 242 343 242 344 241 344
#  241 345 240 345 240 345 239 346 238 346 238 346 237 346 236 346 236 346
#  235 346 234 346 234 346 233 346 233 346" style="fill:purple; stroke:purple; stroke-width:1; fill-opacity:0.5" /><polygon points="230 364 229 364 229 363 229 363 229 362 229 361 229 361 228 360 228 359
#  229 359 229 359 230 359 231 359 231 360 231 360 231 361 231 362 232 362
#  232 363 232 363 232 364 232 365 232 365 232 366 231 366 231 366 230 366
#  230 365" style="fill:red; stroke:red; stroke-width:1; fill-opacity:0.5" /><polygon points="223 372 223 372 223 371 223 371 223 370 223 369 223 369 223 368 224 367
#  224 367 224 366 224 366 224 365 224 364 225 364 225 364 226 364 227 364
#  227 365 227 366 227 366 226 367 226 367 226 368 226 369 226 369 225 370
#  225 370 225 371 225 372 225 372 224 373 224 373 223 373" style="fill:green; stroke:green; stroke-width:1; fill-opacity:0.5" /><polygon points="220 378 220 377 220 377 221 376 221 376 221 375 222 374 222 374 222 373
#  223 373 223 372 224 372 224 372 225 372 226 372 226 372 226 373 226 373
#  226 374 225 374 225 375 224 375 224 376 224 377 223 377 223 378 222 378
#  222 379 222 379 221 379 220 379 220 379" style="fill:orange; stroke:orange; stroke-width:1; fill-opacity:0.5" /><polygon points="188 410 187 410 187 410 186 409 187 409 187 409 188 409 188 408 189 408
#  190 408 190 408 191 408 191 408 192 408 193 408 193 408 194 408 195 408
#  195 409 195 409 195 410 194 410 194 411 193 411 192 411 192 411 191 411
#  190 411 190 411 189 411 188 411" style="fill:salmon; stroke:salmon; stroke-width:1; fill-opacity:0.5" /><polygon points="190 415 191 415 191 414 192 414 192 413 193 413 193 413 194 413 194 412
#  195 412 196 412 196 412 197 411 198 411 198 412 199 412 198 413 198 413
#  197 414 197 414 196 415 196 415 195 415 194 416 194 416 193 416 193 416
#  192 416 191 416 191 416 190 416" style="fill:pink; stroke:pink; stroke-width:1; fill-opacity:0.5" /><polygon points="185 413 184 413 184 412 184 412 184 411 185 411 185 411 186 411 187 411
#  187 411 188 410 188 410 189 410 190 410 190 411 191 411 192 411 192 411
#  193 411 194 411 194 411 194 412 194 412 194 413 193 413 193 413 192 413
#  191 414 191 414 190 414 189 414 189 414 188 414 188 414 187 413 186 413" style="fill:gold; stroke:gold; stroke-width:1; fill-opacity:0.5" /><polygon points="179 420 179 419 179 418 179 418 180 417 180 417 181 417 181 416 182 416
#  183 415 183 415 183 414 184 414 185 414 185 414 186 414 186 414 187 414
#  187 415 187 415 186 416 186 416 186 417 185 417 184 418 184 418 183 418
#  183 419 182 419 181 419 181 420 180 420" style="fill:orchid; stroke:orchid; stroke-width:1; fill-opacity:0.5" /><polygon points="175 419 176 418 176 418 177 417 177 417 178 416 178 416 178 415 179 415
#  180 414 180 414 181 414 181 414 182 414 182 414 182 415 182 415 182 416
#  181 416 181 417 180 417 180 417 180 418 179 418 179 419 178 419 177 419
#  177 420 176 420 176 420 175 420" style="fill:slateblue; stroke:slateblue; stroke-width:1; fill-opacity:0.5" /><polygon points="189 462 189 462 189 461 190 461 190 460 191 460 191 459 192 459 192 458
#  193 458 194 458 194 457 195 457 195 457 196 457 197 457 197 458 197 458
#  197 459 196 460 196 460 196 461 195 461 194 461 194 462 193 462 193 462
#  192 462 191 463 191 463 190 463 189 463 189 463 188 463" style="fill:limegreen; stroke:limegreen; stroke-width:1; fill-opacity:0.5" /><polygon points="161 242 162 242 162 242 163 241 164 241 164 241 165 241 165 240 166 240
#  166 240 167 239 167 239 168 239 168 238 169 238 169 237 169 237 168 237
#  167 237 167 237 166 237 165 238 165 238 164 239 163 239 163 239 162 239
#  162 240 161 240 161 241 160 241 160 242" style="fill:seagreen; stroke:seagreen; stroke-width:1; fill-opacity:0.5" /><polygon points="180 252 180 252 180 251 181 250 181 250 182 250 182 249 183 249 183 248
#  183 248 184 247 185 247 186 247 186 247 186 247 186 248 186 248 186 249
#  185 249 185 250 184 250 184 251 183 251 183 252 182 252 182 252 181 252
#  180 252" style="fill:darkgreen; stroke:darkgreen; stroke-width:1; fill-opacity:0.5" /><polygon points="178 254 179 254 179 255 180 255 181 255 181 255 182 255 183 255 183 255
#  184 256 184 256 185 256 186 256 186 256 187 255 186 254 186 254 186 254
#  185 253 184 253 183 253 183 253 182 253 181 253 180 253 180 253 179 253
#  178 253 178 253" style="fill:olive; stroke:olive; stroke-width:1; fill-opacity:0.5" /><polygon points="188 257 188 257 188 256 188 256 188 255 188 254 188 254 188 253 188 252
#  187 252 187 251 187 250 187 250 186 250 186 249 185 250 185 250 185 251
#  185 252 185 252 186 253 186 253 186 254 186 255 186 255 186 256 187 256
#  187 257 188 257" style="fill:teal; stroke:teal; stroke-width:1; fill-opacity:0.5" /><polygon points="182 258 183 258 184 258 184 258 185 259 185 259 186 259 187 259 187 259
#  188 259 189 259 188 258 188 258 188 257 187 257 187 257 186 256 185 256
#  185 256 184 256 183 255 183 255 182 255 182 255 181 256 181 256 181 257
#  182 257" style="fill:aquamarine; stroke:aquamarine; stroke-width:1; fill-opacity:0.5" /><polygon points="164 350 164 349 164 349 164 348 165 348 166 348 166 348 167 348 167 349
#  168 349 168 350 169 350 169 350 170 351 170 351 171 352 171 352 171 353
#  171 354 171 354 170 354 170 354 169 354 168 354 168 353 167 353 167 352
#  166 352 166 352 165 351 165 351" style="fill:steelblue; stroke:steelblue; stroke-width:1; fill-opacity:0.5" /><polygon points="161 347 161 347 162 347 163 346 163 346 164 345 164 345 165 345 165 345
#  166 344 167 344 168 344 168 344 169 344 170 344 170 344 170 345 170 346
#  170 346 169 347 169 347 168 347 167 347 167 348 166 348 165 348 165 348
#  164 348 164 349 163 349 162 349 162 349 161 349 161 348" style="fill:powderblue; stroke:powderblue; stroke-width:1; fill-opacity:0.5" /><polygon points="138 320 138 320 139 319 139 319 139 318 139 318 139 317 138 316 138 316
#  138 315 138 315 138 314 137 313 137 313 137 312 137 311 136 311 135 311
#  135 311 135 312 135 313 135 313 135 314 135 315 135 315 136 316 136 317
#  136 317 136 318 137 319 137 319 138 319" style="fill:dodgerblue; stroke:dodgerblue; stroke-width:1; fill-opacity:0.5" /><polygon points="136 321 137 322 137 322 138 321 138 321 138 320 137 320 137 319 137 318
#  136 318 136 317 136 317 135 316 135 316 135 315 134 315 134 315 133 315
#  133 316 133 316 133 317 133 318 134 318 134 319 135 319 135 320 135 320
#  136 321" style="fill:navy; stroke:navy; stroke-width:1; fill-opacity:0.5" /><polygon points="144 324 145 324 145 323 145 323 145 322 145 322 144 321 144 320 144 320
#  144 319 144 319 144 318 143 318 143 317 143 316 142 316 142 315 142 315
#  141 315 140 316 140 316 140 317 141 318 141 318 141 319 141 320 141 320
#  142 321 142 321 142 322 142 323 143 323 143 324 143 324" style="fill:magenta; stroke:magenta; stroke-width:1; fill-opacity:0.5" /><polygon points="141 326 142 326 142 327 142 327 143 328 144 328 144 328 145 328 145 327
#  145 326 144 326 144 325 144 325 143 324 143 324 143 323 142 323 142 322
#  141 322 141 321 140 321 140 321 139 321 139 322 139 323 139 323 140 323
#  140 324 140 325 141 325" style="fill:sienna; stroke:sienna; stroke-width:1; fill-opacity:0.5" /><polygon points="115 309 116 310 116 310 117 310 118 310 118 310 119 310 120 310 120 310
#  121 310 122 309 122 309 123 309 123 308 122 308 122 307 121 307 121 307
#  120 307 119 307 119 307 118 307 117 307 117 307 116 307 115 307 115 307
#  11

# %%
image = coco_dataset.images[image_id]
image_file_name = image['file_name']
base = os.path.basename(image_file_name)
image_name_no_changeble = os.path.splitext(base)[0]

image_path = os.path.join(coco_dataset.image_dir, image_file_name)
image = PILImage.open(image_path)
draw = PILImageDraw.Draw(image)
image_width, image_height = image.size
trainning_image_dir = os.path.join(coco_dataset.image_dir,"stage_train_cellpose")

#########################################################################
from itertools import product
l = image_width
h = image_height
num_parts = 6
part_duration = l // num_parts
parts = []
# I rearranged this a bit too
for i in range(0, l, part_duration):
    if i+part_duration > l:
        part = [l-part_duration, l]
    else: 
        part = [i, i+part_duration]
    parts.append(part)
parts_l = parts

num_parts = 4
part_duration = h // num_parts
parts = []
# I rearranged this a bit too
for i in range(0, h, part_duration):
    if i+part_duration > h:
        part = [h-part_duration, h]
    else: 
        part = [i, i+part_duration]
    parts.append(part)
parts_h = parts

C = list(product(parts_l, parts_h))
for txy in C:
    x0 = txy[0][0]
    x1 = txy[0][1]
    y0 = txy[1][0]
    y1 = txy[1][1]
    s = str(x0)+'_'+str(y0)+('_')+str(x1)+'_'+str(y1)
    #print(s)

#########################################################################

print(image_path)
for seg_id, points_list in coco_dataset.polygons_no_scale.items():
    cropped_x0 = 0
    cropped_y0 = 0
    cropped_size = (0,0)    
    points_list_0 = points_list[0]
    first_point_x = points_list_0[0]
    first_point_y = points_list_0[1]
    for txy in C:
        x0 = txy[0][0]
        x1 = txy[0][1]
        y0 = txy[1][0]
        y1 = txy[1][1]
        for xx,yy in zip(points_list_0[0::2], points_list_0[1::2]):
            if(xx >= x0 and xx < x1 and yy >= y0 and yy < y1 ) : 
                # save image if it's never saved
                image_name = image_name_no_changeble + '_' + str(x0)+'_'+str(y0)+('_')+str(x1)+'_'+str(y1)
                image_mask_name = image_name+'_'+str(int(xx))+'_'+str(int(yy))
                #print(image_mask_name)
                image_folder = os.path.join(trainning_image_dir,image_name,"images")
                image_b_folder = os.path.join(trainning_image_dir,image_name,"masks")
                area = (x0, y0, x1, y1)
                cropped_x0 = x0
                cropped_y0 = y0
                cropped_img = image.crop(area)
                cropped_size = cropped_img.size
                if not os.path.isdir(image_folder):
                    cropped_img.convert("LA")
                    os.makedirs(image_folder,exist_ok = True)
                    crop_img_path = os.path.join(image_folder,image_name)
                    cropped_img.save(crop_img_path+'.png','PNG')
                    #print(image_name)

                image_l = PILImage.new('L',cropped_size)
                image_b = PILImageDraw.Draw(image_l)
                list_shift = []
                for xp,yp in zip(points_list_0[0::2], points_list_0[1::2]):
                    list_shift.append(xp-x0)
                    list_shift.append(yp-y0)
                    #print(str(i), '+', str(k), '=', str(i+k)) 
                image_b.polygon(list_shift, fill ="#ffffff")
                #image_l.show()
                if not os.path.isdir(image_b_folder):
                    os.makedirs(image_b_folder,exist_ok=True)
                #print(image_b_folder)
                crop_img_b_name = os.path.join(image_b_folder,image_mask_name)
                image_l.save(crop_img_b_name+'.png','PNG')
                if first_point_x != xx and first_point_y != yy:
                    print('part of polygon fell into image : '+crop_img_b_name)
                break
# Out:
# ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/200728_eggs0004.tif
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_433_646_866_969/masks/200728_eggs0004_433_646_866_969_455_646
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_433_323_866_646/masks/200728_eggs0004_433_323_866_646_479_644
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_433_646_866_969/masks/200728_eggs0004_433_646_866_969_433_892
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_433_646_866_969/masks/200728_eggs0004_433_646_866_969_433_876
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_1732_323_2165_646/masks/200728_eggs0004_1732_323_2165_646_2086_644
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_1732_0_2165_323/masks/200728_eggs0004_1732_0_2165_323_1834_321
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_1299_646_1732_969/masks/200728_eggs0004_1299_646_1732_969_1731_874
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_1732_646_2165_969/masks/200728_eggs0004_1732_646_2165_969_1732_871
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_1299_646_1732_969/masks/200728_eggs0004_1299_646_1732_969_1730_891
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_1299_646_1732_969/masks/200728_eggs0004_1299_646_1732_969_1731_900
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_1299_646_1732_969/masks/200728_eggs0004_1299_646_1732_969_1730_908
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_1299_323_1732_646/masks/200728_eggs0004_1299_323_1732_646_1522_644
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_1299_646_1732_969/masks/200728_eggs0004_1299_646_1732_969_1540_967
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_1299_646_1732_969/masks/200728_eggs0004_1299_646_1732_969_1533_968
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_1299_646_1732_969/masks/200728_eggs0004_1299_646_1732_969_1562_968
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_1299_646_1732_969/masks/200728_eggs0004_1299_646_1732_969_1349_968
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_1299_646_1732_969/masks/200728_eggs0004_1299_646_1732_969_1299_683
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_866_323_1299_646/masks/200728_eggs0004_866_323_1299_646_1069_645
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_866_323_1299_646/masks/200728_eggs0004_866_323_1299_646_1091_645
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_433_646_866_969/masks/200728_eggs0004_433_646_866_969_865_755
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_433_646_866_969/masks/200728_eggs0004_433_646_866_969_865_766
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_433_646_866_969/masks/200728_eggs0004_433_646_866_969_865_768
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_433_646_866_969/masks/200728_eggs0004_433_646_866_969_835_967
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_433_0_866_323/masks/200728_eggs0004_433_0_866_323_433_229
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_0_0_433_323/masks/200728_eggs0004_0_0_433_323_432_308
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_1299_646_1732_969/masks/200728_eggs0004_1299_646_1732_969_1599_968
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_1299_646_1732_969/masks/200728_eggs0004_1299_646_1732_969_1414_968
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_1299_646_1732_969/masks/200728_eggs0004_1299_646_1732_969_1299_699
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_1299_646_1732_969/masks/200728_eggs0004_1299_646_1732_969_1299_691
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_866_969_1299_1292/masks/200728_eggs0004_866_969_1299_1292_1120_969
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_866_970_1299_1293/masks/200728_eggs0004_866_970_1299_1293_1121_971
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_866_646_1299_969/masks/200728_eggs0004_866_646_1299_969_1101_967
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_433_646_866_969/masks/200728_eggs0004_433_646_866_969_865_681
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_866_646_1299_969/masks/200728_eggs0004_866_646_1299_969_866_778
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_0_0_433_323/masks/200728_eggs0004_0_0_433_323_429_322
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_433_0_866_323/masks/200728_eggs0004_433_0_866_323_433_315
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_433_323_866_646/masks/200728_eggs0004_433_323_866_646_435_323
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_0_323_433_646/masks/200728_eggs0004_0_323_433_646_432_451
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_433_323_866_646/masks/200728_eggs0004_433_323_866_646_433_594
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_433_323_866_646/masks/200728_eggs0004_433_323_866_646_433_601
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_0_646_433_969/masks/200728_eggs0004_0_646_433_969_304_646
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_1732_0_2165_323/masks/200728_eggs0004_1732_0_2165_323_2164_35
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_2165_323_2598_646/masks/200728_eggs0004_2165_323_2598_646_2415_644
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_2165_323_2598_646/masks/200728_eggs0004_2165_323_2598_646_2288_644
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_1732_0_2165_323/masks/200728_eggs0004_1732_0_2165_323_1827_321
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_1732_0_2165_323/masks/200728_eggs0004_1732_0_2165_323_1820_322
# part of polygon fell into image : ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/stage_train_cellpose/200728_eggs0004_1732_323_2165_646/masks/200728_eggs0004_1732_323_2165_646_1732_395

# %%
image_id = 9
html = coco_dataset.display_image(image_id, use_url=False,show_polys=True,show_bbox=False)
IPython.display.HTML(html)
# Out:
# Image:
# ======
#   id: 9
#   width: 2612
#   height: 1320
#   file_name: 1_3.tif
#   license: 0
#   flickr_url:
#   coco_url:
#   date_captured: 0
#   segmentations (195):
#     1358:blue:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1359:purple:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1360:red:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1361:green:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1362:orange:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1363:salmon:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1364:pink:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1365:gold:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1366:orchid:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1367:slateblue:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1368:limegreen:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1369:seagreen:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1370:darkgreen:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1371:olive:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1372:teal:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1373:aquamarine:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1374:steelblue:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1375:powderblue:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1376:dodgerblue:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1377:navy:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1378:magenta:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1379:sienna:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1380:maroon:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1381:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1382:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1383:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1384:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1385:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1386:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1387:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1388:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1389:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1390:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1391:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1392:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1393:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1394:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1395:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1396:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1397:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1398:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1399:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1400:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1401:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1402:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1403:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1404:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1405:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1406:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1407:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1408:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1409:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1410:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1411:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1412:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1413:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1414:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1415:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1416:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1417:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1418:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1419:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1420:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1421:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1422:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1423:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1424:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1425:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1426:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1427:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1428:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1429:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1430:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1431:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1432:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1433:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1434:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1435:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1436:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1437:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1438:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1439:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1440:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1441:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1442:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1443:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1444:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1445:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1446:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1447:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1448:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1449:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1450:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1451:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1452:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1453:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1454:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1455:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1456:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1457:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1458:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1459:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1460:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1461:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1462:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1463:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1464:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1465:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1466:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1467:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1468:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1469:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1470:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1471:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1472:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1473:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1474:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1475:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1476:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1477:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1478:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1479:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1480:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1481:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1482:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1483:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1484:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1485:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1486:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1487:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1488:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1489:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1490:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1491:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1492:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1493:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1494:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1495:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1496:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1497:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1498:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1499:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1500:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1501:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1502:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1503:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1504:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1505:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1506:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1507:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1508:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1509:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1510:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1511:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1512:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1513:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1514:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1515:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1516:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1517:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1518:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1519:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1520:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1521:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1522:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1523:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1524:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1525:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1526:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1527:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1528:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1529:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1530:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1531:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1532:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1533:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1534:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1535:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1536:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1537:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1538:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1539:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1540:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1541:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1542:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1543:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1544:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1545:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1546:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1547:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1548:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1549:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1550:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1551:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
#     1552:white:{'id': 1, 'name': 'egg', 'supercategory': ''}
# <div class="container" style="position:relative;"><img src="data:image/png;base64,..." style="position:relative;top:0px;left:0px;width:1024px;"><div class="svgclass"><svg width="1024" height="517.4885145482389"><polygon points="314 304 314 303 314 303 314 302 314 301 313 301 313 300 313 299 313 299
#  314 298 314 297 314 297 315 297 315 297 316 298 316 298 316 299 316 299
#  316 300 316 301 316 301 316 302 316 303 316 303 316 304 316 304 315 305
#  315 305 314 305 314 304" style="fill:blue; stroke:blue; stroke-width:1; fill-opacity:0.5" /><polygon points="152 435 152 434 151 434 150 434 149 433 149 433 148 432 148 432 148 431
#  148 431 149 430 150 430 151 431 151 431 152 431 153 431 153 432 154 432
#  155 432 155 432 156 433 157 433 157 434 157 434 157 435 157 435 156 435
#  155 435 154 435 154 435 153 435" style="fill:purple; stroke:purple; stroke-width:1; fill-opacity:0.5" /><polygon points=" 38 319  38 319  38 318  38 317  38 317  38 316  38 315  39 314  39 314
#   40 313  40 313  41 313  41 314  41 315  41 315  41 316  41 317  41 318
#   41 318  41 319  41 320  41 321  40 322  40 322  40 323  39 323  39 323
#   38 323  38 322  38 322  38 321  38 320" style="fill:red; stroke:red; stroke-width:1; fill-opacity:0.5" /><polygon points=" 58 313  57 313  57 313  56 313  56 312  55 311  55 311  56 310  56 310
#   57 310  57 310  58 310  59 310  59 311  60 311  61 311  61 312  62 312
#   63 312  63 313  63 313  64 314  64 314  64 315  64 316  63 316  62 316
#   62 316  61 315  60 315  60 315  59 314  59 314  58 314" style="fill:green; stroke:green; stroke-width:1; fill-opacity:0.5" /><polygon points=" 70 346  70 346  69 346  69 345  69 345  69 344  70 344  71 344  71 344
#   72 344  73 344  73 344  74 343  75 343  76 343  76 343  77 343  78 344
#   78 344  79 344  79 345  79 345  78 346  78 346  77 346  76 347  76 347
#   75 347  75 347  74 347  73 347  73 346  72 346  71 346  71 346" style="fill:orange; stroke:orange; stroke-width:1; fill-opacity:0.5" /><polygon points=" 82 345  82 344  81 343  81 343  81 342  81 341  81 340  81 340  81 339
#   82 339  82 339  83 339  83 340  84 340  84 341  84 341  84 342  85 343
#   85 343  85 344  85 345  85 345  85 346  85 347  85 347  85 348  84 348
#   84 348  83 348  83 347  83 347  83 346  82 346  82 345" style="fill:salmon; stroke:salmon; stroke-width:1; fill-opacity:0.5" /><polygon points=" 85 339  84 338  84 337  84 337  84 336  84 336  84 335  85 334  85 334
#   86 334  86 333  87 334  87 335  87 335  87 336  88 337  88 338  88 338
#   88 339  88 340  88 340  88 341  87 342  87 342  86 342  86 342  85 342
#   85 341  85 341  85 340  85 339" style="fill:pink; stroke:pink; stroke-width:1; fill-opacity:0.5" /><polygon points="112 348 112 348 112 347 111 347 111 346 111 346 110 345 110 344 110 344
#  111 343 112 343 112 344 113 344 113 345 114 346 114 346 115 347 116 347
#  116 348 116 349 117 349 117 350 117 350 117 351 116 352 116 351 115 351
#  115 350 114 350 113 349 113 349" style="fill:gold; stroke:gold; stroke-width:1; fill-opacity:0.5" /><polygon points="122 412 123 413 124 413 125 413 125 413 126 414 126 414 127 414 128 414
#  128 415 129 415 129 416 129 416 129 417 129 417 128 417 127 417 127 417
#  126 417 125 417 125 416 124 416 123 416 123 416 122 416 122 415 121 415
#  121 415 120 414 120 414 120 413 120 413 121 412 121 412" style="fill:orchid; stroke:orchid; stroke-width:1; fill-opacity:0.5" /><polygon points="115 404 116 404 116 403 117 403 117 403 118 402 118 402 119 402 120 402
#  120 402 121 402 121 403 120 404 120 404 119 405 119 406 119 406 118 407
#  118 407 117 408 116 408 116 409 116 409 115 409 114 410 114 410 113 410
#  113 410 112 410 112 409 112 408 113 408 113 407 113 407 114 406 114 406
#  115 405" style="fill:slateblue; stroke:slateblue; stroke-width:1; fill-opacity:0.5" /><polygon points="105 404 106 404 106 403 107 403 108 403 108 403 109 404 110 404 111 404
#  111 404 112 404 113 404 113 405 114 405 114 405 114 406 114 407 114 407
#  113 407 112 407 112 407 111 407 110 407 109 407 109 407 108 407 107 407
#  107 406 106 406 106 406 105 405 105 405 105 404" style="fill:limegreen; stroke:limegreen; stroke-width:1; fill-opacity:0.5" /><polygon points="100 403 100 403 101 403 102 404 102 404 103 404 104 404 104 405 105 405
#  105 405 106 406 107 406 107 407 107 407 107 408 106 408 106 408 105 408
#  104 408 104 408 103 408 102 407 101 407 101 407 100 407 100 407  99 406
#   98 406  98 405  98 404  98 404  98 403  99 403" style="fill:seagreen; stroke:seagreen; stroke-width:1; fill-opacity:0.5" /><polygon points=" 96 401  96 401  97 400  97 399  97 399  98 398  98 398  99 397  99 397
#  100 396 100 396 101 396 101 397 101 398 101 398 101 399 101 400 100 400
#  100 401 100 401  99 402  99 403  98 403  98 404  97 404  97 405  96 405
#   96 406  95 406  95 406  94 405  94 405  95 404  95 404  95 403  95 402
#   96 402" style="fill:darkgreen; stroke:darkgreen; stroke-width:1; fill-opacity:0.5" /><polygon points="117 392 117 392 118 391 119 391 120 391 120 391 121 391 121 391 121 392
#  121 393 120 393 120 394 120 394 119 395 119 395 118 395 118 396 117 396
#  116 397 116 397 115 397 115 397 114 398 113 398 113 398 112 398 112 397
#  112 396 112 396 113 395 113 395 114 394 114 393 115 393 115 393 116 392
#  116 392" style="fill:olive; stroke:olive; stroke-width:1; fill-opacity:0.5" /><polygon points="118 389 117 389 117 389 116 388 115 388 115 388 114 387 114 387 114 386
#  114 386 115 385 115 385 116 386 117 386 117 386 118 386 118 387 119 387
#  120 387 120 387 121 388 122 388 122 388 122 389 123 389 123 390 123 391
#  122 391 122 391 121 391 120 391 120 390 119 390 119 390 118 390" style="fill:teal; stroke:teal; stroke-width:1; fill-opacity:0.5" /><polygon points="113 390 112 389 112 389 112 388 111 387 111 387 111 386 111 385 111 385
#  112 385 112 385 113 385 113 386 114 386 114 387 115 387 115 388 115 389
#  116 389 116 390 116 391 116 391 116 392 116 392 116 393 115 393 115 393
#  114 392 114 391 113 391 113 390" style="fill:aquamarine; stroke:aquamarine; stroke-width:1; fill-opacity:0.5" /><polygon points="186 324 186 324 187 325 187 325 188 326 188 326 189 326 189 327 190 327
#  190 328 191 328 191 329 192 329 192 330 192 330 192 331 192 332 192 332
#  191 332 191 332 190 332 189 332 189 331 188 331 187 330 187 330 186 330
#  186 329 185 329 185 328 185 327 184 327 184 326 184 326 184 325 185 324" style="fill:steelblue; stroke:steelblue; stroke-width:1; fill-opacity:0.5" /><polygon points="149 342 149 341 149 341 149 340 149 339 149 338 149 338 150 337 150 337
#  151 337 151 337 152 338 152 338 152 339 152 340 152 340 152 341 152 342
#  152 342 152 343 152 344 152 344 152 345 151 346 151 346 150 346 149 346
#  149 346 149 345 149 345 149 344 149 343 149 343" style="fill:powderblue; stroke:powderblue; stroke-width:1; fill-opacity:0.5" /><polygon points="153 340 153 340 154 340 155 341 155 341 156 342 156 342 156 343 157 344
#  157 344 158 345 158 345 158 346 158 346 158 347 158 348 157 348 157 348
#  156 347 155 347 155 347 154 346 153 346 153 345 152 345 152 344 152 343
#  152 343 151 342 151 341 151 341 152 340 152 340" style="fill:dodgerblue; stroke:dodgerblue; stroke-width:1; fill-opacity:0.5" /><polygon points="153 366 153 366 154 365 154 365 155 364 155 364 156 364 157 363 157 363
#  158 363 159 363 159 363 160 363 160 364 160 364 159 365 159 366 158 366
#  158 366 157 367 157 367 156 368 156 368 155 369 154 369 154 369 153 370
#  153 370 152 370 151 370 151 369 151 369 151 368 152 367 152 367" style="fill:navy; stroke:navy; stroke-width:1; fill-opacity:0.5" /><polygon points="171 399 170 399 170 399 169 399 169 398 168 398 167 398 167 397 168 397
#  168 396 169 396 170 396 170 396 171 396 172 396 173 397 173 397 174 397
#  175 397 175 397 176 398 176 398 176 399 175 399 175 399 174 399 174 399
#  173 399 172 399 172 399" style="fill:magenta; stroke:magenta; stroke-width:1; fill-opacity:0.5" /><polygon points="176 402 175 402 174 402 174 401 174 401 174 400 174 400 175 400 176 400
#  176 399 177 399 178 399 179 399 179 399 180 399 181 399 181 399 182 399
#  183 399 183 400 184 400 185 400 185 401 184 401 183

# %% [markdown]
# # CELLPOSE

# %%
image = coco_dataset.images[image_id]
image_file_name = image['file_name']
base = os.path.basename(image_file_name)
image_name_no_changeble = os.path.splitext(base)[0]

image_path = os.path.join(coco_dataset.image_dir, image_file_name)
image = PILImage.open(image_path)
draw = PILImageDraw.Draw(image)
image_width, image_height = image.size
trainning_image_dir = os.path.join(coco_dataset.image_dir,"stage_train_cellpose")

#########################################################################
from itertools import product
from PIL import Image
import PIL.ImageOps    

l = image_width
h = image_height
num_parts = 6
part_duration = l // num_parts
parts = []
# I rearranged this a bit too
for i in range(0, l, part_duration):
    if i+part_duration > l:
        part = [l-part_duration, l]
    else: 
        part = [i, i+part_duration]
    parts.append(part)
parts_l = parts

num_parts = 4
part_duration = h // num_parts
parts = []
# I rearranged this a bit too
for i in range(0, h, part_duration):
    if i+part_duration > h:
        part = [h-part_duration, h]
    else: 
        part = [i, i+part_duration]
    parts.append(part)
parts_h = parts

C = list(product(parts_l, parts_h))
for txy in C:
    x0 = txy[0][0]
    x1 = txy[0][1]
    y0 = txy[1][0]
    y1 = txy[1][1]
    s = str(x0)+'_'+str(y0)+('_')+str(x1)+'_'+str(y1)
    #print(s)

#########################################################################

print(image_path)

image_folder = os.path.join(trainning_image_dir,"Images")
image_b_folder = os.path.join(trainning_image_dir,"Masks")
                
if not os.path.isdir(image_folder):
    os.makedirs(image_folder,exist_ok = True)
if not os.path.isdir(image_b_folder):
    os.makedirs(image_b_folder,exist_ok = True)
    
for txy in C:
    x0 = txy[0][0]
    x1 = txy[0][1]
    y0 = txy[1][0]
    y1 = txy[1][1]   
    image_name = image_name_no_changeble + '_' + str(x0)+'_'+str(y0)+('_')+str(x1)+'_'+str(y1)
    #print(image_mask_name)
    area = (x0, y0, x1, y1)
    cropped_x0 = x0
    cropped_y0 = y0
    cropped_img = image.crop(area)
    cropped_size = cropped_img.size
    if not os.path.isfile(image_name+'.tif'):
        cropped_img.convert("LA")
        crop_img_path = os.path.join(image_folder,image_name)
        cropped_img = PIL.ImageOps.invert(cropped_img)
        cropped_img.save(crop_img_path+'.tif',format=None)
        #print(image_name)
        image_l = PILImage.new('L',cropped_size)
        image_b = PILImageDraw.Draw(image_l)
    
    fill_value = 1
    for seg_id, points_list in coco_dataset.polygons_no_scale.items():
        cropped_x0 = 0
        cropped_y0 = 0
        cropped_size = (0,0)    
        points_list_0 = points_list[0]
        for xx,yy in zip(points_list_0[0::2], points_list_0[1::2]):
            if(xx >= x0 and xx < x1 and yy >= y0 and yy < y1 ): 
                list_shift = []
                for xp,yp in zip(points_list_0[0::2], points_list_0[1::2]):
                    list_shift.append(xp-x0)
                    list_shift.append(yp-y0)
                image_b.polygon(list_shift, fill = fill_value)#
                fill_value = fill_value+1
                break
                #image_l.show()
    #image_l.show()
    crop_mask_path = os.path.join(image_b_folder,image_name)
    image_l.save(crop_mask_path+'.tif',format=None)
# Out:
# ./task_egg-felix-cri-2020_11_19_18_43_49-coco 1.0/images/1_3.tif
